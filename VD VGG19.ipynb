# %%
from tensorflow.keras.layers import Input, Dense, GlobalAveragePooling2D,BatchNormalization,Activation, Dropout, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import Callback, ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping, ReduceLROnPlateau
import numpy as np
import pandas as pd
import seaborn as sns
import random
import os
import cv2
import time
import datetime
import imageio
import imgaug.augmenters as iaa
import imgaug as ia
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import StratifiedShuffleSplit
from tensorflow.keras import regularizers
from sklearn.utils import class_weight
from tensorflow.keras.models import load_model

# %%
img_size =  128
num_channels = 3
batch_size = 32

# %%
def video_to_frames(video):
    cap = cv2.VideoCapture(video)  # Open the video file for reading frames
    
    frames_list = []  # List to store the processed image frames
    while cap.isOpened():  # Loop until the video has been completely processed
        ID = cap.get(1)  # Get the current frame ID (1 corresponds to the frame number)
        success, image = cap.read()  # Read the next frame from the video

        if success:  # If the frame was read successfully
            # Skip frames to avoid duplications; process every 7th frame
            if (ID % 7 == 0):  
                # Define image augmentations
                flip = iaa.Fliplr(1.0)  # Always flip the image horizontally (left to right)
                zoom = iaa.Affine(scale=1.3)  # Zoom the image by 30%
                random_brightness = iaa.Multiply((1, 1.3))  # Adjust brightness randomly (between 100% and 130%)
                rotate = iaa.Affine(rotate=(-25, 25))  # Rotate the image randomly between -25 and 25 degrees

                # Apply augmentations in sequence
                aug = flip(image=image)  # Apply horizontal flip
                aug = random_brightness(image= aug)  # Adjust brightness
                aug = zoom(image= aug)  # Apply zoom
                aug = rotate(image= aug)  # Apply rotation
                
                # Convert the augmented image from BGR (OpenCV fimg_siz feormat) to RGB (common format)
                to_rgb = cv2.cvtColor(aug, cv2.COLOR_BGR2RGB)
                # Resize the image to the specified dimensions
                resized = cv2.resize(to_rgb, (img_size, img_size))
                frames_list.append(resized)  # Add the resized image to the list of frames
               
        else:
            break  
    
    cap.release()  # Release the video capture object
    
    return frames_list  # Return the list of processed image frames

# %%
VideoData = 'Test Dataset'  # 'Train' folder contains  each class ("NonViolence" and "Violence")


X  = [] # List to store frames (image data) extracted from videos
y  = [] # List to store labels corresponding to each frame


classes = ["NonViolence", "Violence"]   # Classes: NonViolence = 0, Violence = 1

# Loop through each class folder in the 'Train' directory
for category in os.listdir(VideoData): 
    path = os.path.join(VideoData, category)  
    class_num = classes.index(category)       # Get the numeric label for the current category (0 or 1)

    # Loop through each video in the current category folder
    for i, video in enumerate(os.listdir(path)): 
        frames = video_to_frames(path + '/' + video)  # Extract frames from the video using the video_to_frames function
        
        # Loop through each frame extracted from the video
        for j, frame in enumerate(frames): 
            X.append(frame)                    
            y.append(class_num)

# %%
# Convert the lists of frames and labels into NumPy arrays
X = np.array(X)
y = np.array(y)                                       

print(len(X))
# Out:
# 15598

# %%
# First split - Train (70%) vs Temp (30%)
stratified = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=73)

for train_index, temp_index in stratified.split(X, y):
    X_train, X_temp = X[train_index], X[temp_index]
    y_train, y_temp = y[train_index], y[temp_index]

# Second split - Temp (15%) into Validation (50% of Temp) and Test (50% of Temp)
stratified1 = StratifiedShuffleSplit(n_splits=1, test_size=0.5, random_state=73)

for val_index, test_index in stratified1.split(X_temp, y_temp):
    X_val, X_test = X_temp[val_index], X_temp[test_index]
    y_val, y_test = y_temp[val_index], y_temp[test_index]

# %%
# Normalize the pixel values
X_train_norm = X_train/ 255
X_test_norm = X_test / 255
X_val_norm = X_val/ 255

# %%
print("Training set shape:", X_train_norm.shape, y_train.shape)
print("Validation set shape:", X_val_norm.shape, y_val.shape)
print("Test set shape:", X_test_norm.shape, y_test.shape)
# Out:
# Training set shape: (10918, 128, 128, 3) (10918,)
# Validation set shape: (2340, 128, 128, 3) (2340,)
# Test set shape: (2340, 128, 128, 3) (2340,)

# %%
# L2 regularization with a strength of 0.0001 to prevent overfitting
kernel_regularizer = regularizers.l2(0.0001)  

vgg = VGG19(input_shape=(img_size,img_size,num_channels), weights='imagenet', include_top=False)
#freezing pre-trained layers of VGG-19
for layer in vgg.layers:
    layer.trainable = False
# Add the custom layers on top of VGG19
x = vgg.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation="relu",kernel_regularizer=kernel_regularizer)(x)  # Add dense layer with 256 units and ReLU activation

# Final sigmoid layer for binary classification
prediction = Dense(1, activation='sigmoid',kernel_regularizer=kernel_regularizer)(x)

# Combine the VGG19 base and custom layers
model = Model(inputs=vgg.input, outputs=prediction)
# Print a message indicating that the model is being compiled
print("Compiling model...")  

# Compile the model with binary crossentropy loss, Adam optimizer, and accuracy as the evaluation metric
model.compile(loss="binary_crossentropy", 
              optimizer='adam', 
              metrics=["accuracy"])  

# Print a summary of the model architecture, including layer types and output shapes
model.summary()
# Out:
# Compiling model...
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 128, 128, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 128, 128, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 64, 64, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 64, 64, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 32, 32, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 32, 32, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 32, 32, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv4 (Conv2D)           │ (None, 32, 32, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 16, 16, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 16, 16, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 16, 16, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv4 (Conv2D)           │ (None, 16, 16, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 8, 8, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 8, 8, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 8, 8, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 8, 8, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv4 (Conv2D)           │ (None, 8, 8, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 4, 4, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,155,969 (76.89 MB)
#  Trainable params: 131,585 (514.00 KB)
#  Non-trainable params: 20,024,384 (76.39 MB)

# %%
# Define parameters for learning rate scheduling and early stopping
epochs = 100
patience = 5
start_lr = 1e-5
max_lr = 2e-4
min_lr = 1e-6

rampup_epochs = 8
sustain_epochs = 0
exp_decay = 0.9

def lrfn(epoch):
    if epoch < rampup_epochs:
        return (max_lr - start_lr) / rampup_epochs * epoch + start_lr
    elif epoch < rampup_epochs + sustain_epochs:
        return max_lr
    else:
        return (max_lr - min_lr) * exp_decay ** (epoch - rampup_epochs - sustain_epochs) + min_lr

class myCallback(Callback):
    def on_epoch_end(self, epoch, logs={}):
        if logs.get('accuracy') >= 0.999:
            print("\nLimits Reached, cancelling training!")
            self.model.stop_training = True


end_callback = myCallback()

lr_callback = LearningRateScheduler(lambda epoch: lrfn(epoch), verbose=False)

early_stopping = EarlyStopping(patience = patience, monitor='val_loss',
                                 mode='min', restore_best_weights=True,
                                 verbose = 1, min_delta = .00075)


lr_plat = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=patience, min_lr=1e-7)

os.system('rm -rf ./logs/')


log_dir="logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir = log_dir, write_graph=True, histogram_freq=1)

checkpoint_filepath = 'VGG19ModelWeights.weights.h5'
model_checkpoints = ModelCheckpoint(filepath=checkpoint_filepath,
                                        save_weights_only=True,
                                        monitor='val_loss',
                                        mode='min',
                                        verbose = 1,
                                        save_best_only=True)


callbacks = [end_callback, lr_callback, model_checkpoints, tensorboard_callback, early_stopping, lr_plat]

# %%
# Training the model head 
print('Training head...')

# Start the timer before training
start_time = time.time()

history = model.fit(
    X_train_norm,                   # Training data normalized for input to the model.
    y_train,                        # Corresponding labels for the training data.
    epochs=epochs,                  # Number of epochs to train the model.
    callbacks=callbacks,            # List of callbacks to apply during training (like early stopping, learning rate adjustments).
    validation_data=(X_val_norm, y_val),  # Validation data and labels for evaluating model performance during training.
    batch_size=batch_size           # Number of samples per gradient update.
)
# End the timer after training
end_time = time.time()

# Notify the user that the best weights are being restored after training is complete.
print('\nRestoring best weights for VGG19')

# Calculate the total training time
training_time = end_time - start_time
print(f"Total training time: {training_time:.2f} seconds")

# Load the best model weights that were saved during training based on the validation loss.
model.load_weights(checkpoint_filepath)
# Out:
# Training head...
# Epoch 1/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5780 - loss: 0.7088
# Epoch 1: val_loss improved from inf to 0.66541, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 429s 1s/step - accuracy: 0.5782 - loss: 0.7088 - val_accuracy: 0.7184 - val_loss: 0.6654 - learning_rate: 1.0000e-05
# Epoch 2/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 935ms/step - accuracy: 0.7600 - loss: 0.6246
# Epoch 2: val_loss improved from 0.66541 to 0.55132, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 391s 1s/step - accuracy: 0.7600 - loss: 0.6245 - val_accuracy: 0.7744 - val_loss: 0.5513 - learning_rate: 3.3750e-05
# Epoch 3/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 925ms/step - accuracy: 0.7925 - loss: 0.5110
# Epoch 3: val_loss improved from 0.55132 to 0.47570, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 387s 1s/step - accuracy: 0.7926 - loss: 0.5109 - val_accuracy: 0.7936 - val_loss: 0.4757 - learning_rate: 5.7500e-05
# Epoch 4/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 920ms/step - accuracy: 0.8162 - loss: 0.4396
# Epoch 4: val_loss improved from 0.47570 to 0.43810, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 385s 1s/step - accuracy: 0.8162 - loss: 0.4396 - val_accuracy: 0.8064 - val_loss: 0.4381 - learning_rate: 8.1250e-05
# Epoch 5/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 915ms/step - accuracy: 0.8266 - loss: 0.4035
# Epoch 5: val_loss improved from 0.43810 to 0.41116, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 384s 1s/step - accuracy: 0.8266 - loss: 0.4035 - val_accuracy: 0.8222 - val_loss: 0.4112 - learning_rate: 1.0500e-04
# Epoch 6/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 916ms/step - accuracy: 0.8370 - loss: 0.3798
# Epoch 6: val_loss improved from 0.41116 to 0.38864, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 383s 1s/step - accuracy: 0.8370 - loss: 0.3798 - val_accuracy: 0.8329 - val_loss: 0.3886 - learning_rate: 1.2875e-04
# Epoch 7/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 918ms/step - accuracy: 0.8509 - loss: 0.3544
# Epoch 7: val_loss improved from 0.38864 to 0.38864, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 383s 1s/step - accuracy: 0.8509 - loss: 0.3544 - val_accuracy: 0.8389 - val_loss: 0.3886 - learning_rate: 1.5250e-04
# Epoch 8/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 913ms/step - accuracy: 0.8654 - loss: 0.3356
# Epoch 8: val_loss improved from 0.38864 to 0.35268, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 381s 1s/step - accuracy: 0.8654 - loss: 0.3356 - val_accuracy: 0.8517 - val_loss: 0.3527 - learning_rate: 1.7625e-04
# Epoch 9/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 942ms/step - accuracy: 0.8692 - loss: 0.3219
# Epoch 9: val_loss improved from 0.35268 to 0.33740, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 393s 1s/step - accuracy: 0.8692 - loss: 0.3219 - val_accuracy: 0.8671 - val_loss: 0.3374 - learning_rate: 2.0000e-04
# Epoch 10/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 919ms/step - accuracy: 0.8807 - loss: 0.3052
# Epoch 10: val_loss improved from 0.33740 to 0.32489, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 384s 1s/step - accuracy: 0.8807 - loss: 0.3052 - val_accuracy: 0.8679 - val_loss: 0.3249 - learning_rate: 1.8010e-04
# Epoch 11/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 915ms/step - accuracy: 0.8895 - loss: 0.2856
# Epoch 11: val_loss improved from 0.32489 to 0.31056, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 383s 1s/step - accuracy: 0.8895 - loss: 0.2856 - val_accuracy: 0.8731 - val_loss: 0.3106 - learning_rate: 1.6219e-04
# Epoch 12/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 916ms/step - accuracy: 0.8912 - loss: 0.2841
# Epoch 12: val_loss improved from 0.31056 to 0.30471, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 384s 1s/step - accuracy: 0.8912 - loss: 0.2841 - val_accuracy: 0.8769 - val_loss: 0.3047 - learning_rate: 1.4607e-04
# Epoch 13/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 922ms/step - accuracy: 0.8930 - loss: 0.2769
# Epoch 13: val_loss did not improve from 0.30471
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 384s 1s/step - accuracy: 0.8930 - loss: 0.2769 - val_accuracy: 0.8803 - val_loss: 0.3051 - learning_rate: 1.3156e-04
# Epoch 14/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 917ms/step - accuracy: 0.8972 - loss: 0.2656
# Epoch 14: val_loss improved from 0.30471 to 0.29334, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 382s 1s/step - accuracy: 0.8972 - loss: 0.2656 - val_accuracy: 0.8885 - val_loss: 0.2933 - learning_rate: 1.1851e-04
# Epoch 15/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 920ms/step - accuracy: 0.9048 - loss: 0.2619
# Epoch 15: val_loss improved from 0.29334 to 0.28831, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 385s 1s/step - accuracy: 0.9048 - loss: 0.2618 - val_accuracy: 0.8876 - val_loss: 0.2883 - learning_rate: 1.0676e-04
# Epoch 16/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 927ms/step - accuracy: 0.9029 - loss: 0.2593
# Epoch 16: val_loss improved from 0.28831 to 0.28689, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 386s 1s/step - accuracy: 0.9029 - loss: 0.2593 - val_accuracy: 0.8885 - val_loss: 0.2869 - learning_rate: 9.6181e-05
# Epoch 17/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 913ms/step - accuracy: 0.9072 - loss: 0.2485
# Epoch 17: val_loss improved from 0.28689 to 0.28094, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 382s 1s/step - accuracy: 0.9072 - loss: 0.2485 - val_accuracy: 0.8919 - val_loss: 0.2809 - learning_rate: 8.6663e-05
# Epoch 18/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 923ms/step - accuracy: 0.9101 - loss: 0.2484
# Epoch 18: val_loss improved from 0.28094 to 0.27624, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 385s 1s/step - accuracy: 0.9101 - loss: 0.2484 - val_accuracy: 0.8953 - val_loss: 0.2762 - learning_rate: 7.8097e-05
# Epoch 19/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 917ms/step - accuracy: 0.9129 - loss: 0.2367
# Epoch 19: val_loss improved from 0.27624 to 0.27617, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 383s 1s/step - accuracy: 0.9129 - loss: 0.2367 - val_accuracy: 0.8966 - val_loss: 0.2762 - learning_rate: 7.0387e-05
# Epoch 20/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 913ms/step - accuracy: 0.9097 - loss: 0.2435
# Epoch 20: val_loss did not improve from 0.27617
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 381s 1s/step - accuracy: 0.9097 - loss: 0.2435 - val_accuracy: 0.8940 - val_loss: 0.2839 - learning_rate: 6.3448e-05
# Epoch 21/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 912ms/step - accuracy: 0.9092 - loss: 0.2446
# Epoch 21: val_loss improved from 0.27617 to 0.26921, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 381s 1s/step - accuracy: 0.9092 - loss: 0.2446 - val_accuracy: 0.8970 - val_loss: 0.2692 - learning_rate: 5.7203e-05
# Epoch 22/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 917ms/step - accuracy: 0.9139 - loss: 0.2363
# Epoch 22: val_loss improved from 0.26921 to 0.26809, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 385s 1s/step - accuracy: 0.9139 - loss: 0.2363 - val_accuracy: 0.9000 - val_loss: 0.2681 - learning_rate: 5.1583e-05
# Epoch 23/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 917ms/step - accuracy: 0.9170 - loss: 0.2342
# Epoch 23: val_loss improved from 0.26809 to 0.26660, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 383s 1s/step - accuracy: 0.9170 - loss: 0.2342 - val_accuracy: 0.8983 - val_loss: 0.2666 - learning_rate: 4.6525e-05
# Epoch 24/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 919ms/step - accuracy: 0.9151 - loss: 0.2373
# Epoch 24: val_loss improved from 0.26660 to 0.26509, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 383s 1s/step - accuracy: 0.9151 - loss: 0.2372 - val_accuracy: 0.8970 - val_loss: 0.2651 - learning_rate: 4.1972e-05
# Epoch 25/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 920ms/step - accuracy: 0.9177 - loss: 0.2341
# Epoch 25: val_loss improved from 0.26509 to 0.26382, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 383s 1s/step - accuracy: 0.9177 - loss: 0.2341 - val_accuracy: 0.8996 - val_loss: 0.2638 - learning_rate: 3.7875e-05
# Epoch 26/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 932ms/step - accuracy: 0.9154 - loss: 0.2308
# Epoch 26: val_loss did not improve from 0.26382
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 387s 1s/step - accuracy: 0.9154 - loss: 0.2308 - val_accuracy: 0.8996 - val_loss: 0.2645 - learning_rate: 3.4188e-05
# Epoch 27/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 923ms/step - accuracy: 0.9145 - loss: 0.2344
# Epoch 27: val_loss improved from 0.26382 to 0.26178, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 387s 1s/step - accuracy: 0.9145 - loss: 0.2344 - val_accuracy: 0.9021 - val_loss: 0.2618 - learning_rate: 3.0869e-05
# Epoch 28/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 923ms/step - accuracy: 0.9150 - loss: 0.2346
# Epoch 28: val_loss improved from 0.26178 to 0.26103, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 386s 1s/step - accuracy: 0.9151 - loss: 0.2345 - val_accuracy: 0.9026 - val_loss: 0.2610 - learning_rate: 2.7882e-05
# Epoch 29/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 920ms/step - accuracy: 0.9202 - loss: 0.2246
# Epoch 29: val_loss did not improve from 0.26103
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 384s 1s/step - accuracy: 0.9202 - loss: 0.2246 - val_accuracy: 0.9047 - val_loss: 0.2611 - learning_rate: 2.5194e-05
# Epoch 30/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 926ms/step - accuracy: 0.9218 - loss: 0.2244
# Epoch 30: val_loss improved from 0.26103 to 0.25960, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 387s 1s/step - accuracy: 0.9218 - loss: 0.2244 - val_accuracy: 0.9038 - val_loss: 0.2596 - learning_rate: 2.2774e-05
# Epoch 31/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 926ms/step - accuracy: 0.9218 - loss: 0.2259
# Epoch 31: val_loss improved from 0.25960 to 0.25871, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 386s 1s/step - accuracy: 0.9218 - loss: 0.2259 - val_accuracy: 0.9034 - val_loss: 0.2587 - learning_rate: 2.0597e-05
# Epoch 32/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 923ms/step - accuracy: 0.9244 - loss: 0.2220
# Epoch 32: val_loss did not improve from 0.25871
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 385s 1s/step - accuracy: 0.9244 - loss: 0.2220 - val_accuracy: 0.9043 - val_loss: 0.2607 - learning_rate: 1.8637e-05
# Epoch 33/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 931ms/step - accuracy: 0.9261 - loss: 0.2162
# Epoch 33: val_loss did not improve from 0.25871
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 388s 1s/step - accuracy: 0.9261 - loss: 0.2163 - val_accuracy: 0.9047 - val_loss: 0.2595 - learning_rate: 1.6874e-05
# Epoch 34/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 925ms/step - accuracy: 0.9212 - loss: 0.2250
# Epoch 34: val_loss improved from 0.25871 to 0.25782, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 392s 1s/step - accuracy: 0.9212 - loss: 0.2250 - val_accuracy: 0.9081 - val_loss: 0.2578 - learning_rate: 1.5286e-05
# Epoch 35/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 931ms/step - accuracy: 0.9163 - loss: 0.2280
# Epoch 35: val_loss improved from 0.25782 to 0.25724, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 388s 1s/step - accuracy: 0.9163 - loss: 0.2280 - val_accuracy: 0.9060 - val_loss: 0.2572 - learning_rate: 1.3858e-05
# Epoch 36/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 930ms/step - accuracy: 0.9237 - loss: 0.2208
# Epoch 36: val_loss improved from 0.25724 to 0.25660, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 388s 1s/step - accuracy: 0.9237 - loss: 0.2208 - val_accuracy: 0.9051 - val_loss: 0.2566 - learning_rate: 1.2572e-05
# Epoch 37/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 987ms/step - accuracy: 0.9228 - loss: 0.2221
# Epoch 37: val_loss improved from 0.25660 to 0.25632, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 464s 1s/step - accuracy: 0.9228 - loss: 0.2221 - val_accuracy: 0.9060 - val_loss: 0.2563 - learning_rate: 1.1415e-05
# Epoch 38/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 956ms/step - accuracy: 0.9178 - loss: 0.2291
# Epoch 38: val_loss improved from 0.25632 to 0.25600, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 399s 1s/step - accuracy: 0.9178 - loss: 0.2291 - val_accuracy: 0.9056 - val_loss: 0.2560 - learning_rate: 1.0373e-05
# Epoch 39/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 962ms/step - accuracy: 0.9229 - loss: 0.2246
# Epoch 39: val_loss improved from 0.25600 to 0.25577, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 401s 1s/step - accuracy: 0.9229 - loss: 0.2246 - val_accuracy: 0.9064 - val_loss: 0.2558 - learning_rate: 9.4358e-06
# Epoch 40/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 957ms/step - accuracy: 0.9218 - loss: 0.2194
# Epoch 40: val_loss improved from 0.25577 to 0.25542, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 398s 1s/step - accuracy: 0.9218 - loss: 0.2194 - val_accuracy: 0.9060 - val_loss: 0.2554 - learning_rate: 8.5923e-06
# Epoch 41/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9225 - loss: 0.2178
# Epoch 41: val_loss did not improve from 0.25542
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 431s 1s/step - accuracy: 0.9225 - loss: 0.2178 - val_accuracy: 0.9085 - val_loss: 0.2560 - learning_rate: 7.8330e-06
# Epoch 42/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9213 - loss: 0.2183
# Epoch 42: val_loss improved from 0.25542 to 0.25503, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 426s 1s/step - accuracy: 0.9213 - loss: 0.2183 - val_accuracy: 0.9060 - val_loss: 0.2550 - learning_rate: 7.1497e-06
# Epoch 43/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9205 - loss: 0.2229
# Epoch 43: val_loss improved from 0.25503 to 0.25489, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 420s 1s/step - accuracy: 0.9205 - loss: 0.2229 - val_accuracy: 0.9073 - val_loss: 0.2549 - learning_rate: 6.5348e-06
# Epoch 44/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 992ms/step - accuracy: 0.9244 - loss: 0.2201
# Epoch 44: val_loss improved from 0.25489 to 0.25468, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 412s 1s/step - accuracy: 0.9244 - loss: 0.2201 - val_accuracy: 0.9085 - val_loss: 0.2547 - learning_rate: 5.9813e-06
# Epoch 45/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 977ms/step - accuracy: 0.9237 - loss: 0.2186
# Epoch 45: val_loss did not improve from 0.25468
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 406s 1s/step - accuracy: 0.9236 - loss: 0.2186 - val_accuracy: 0.9068 - val_loss: 0.2549 - learning_rate: 5.4832e-06
# Epoch 46/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 935ms/step - accuracy: 0.9186 - loss: 0.2224
# Epoch 46: val_loss did not improve from 0.25468
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 392s 1s/step - accuracy: 0.9186 - loss: 0.2224 - val_accuracy: 0.9085 - val_loss: 0.2551 - learning_rate: 5.0348e-06
# Epoch 47/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 935ms/step - accuracy: 0.9201 - loss: 0.2217
# Epoch 47: val_loss improved from 0.25468 to 0.25451, saving model to VGG19ModelWeights.weights.h5
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 391s 1s/step - accuracy: 0.9201 - loss: 0.2217 - val_accuracy: 0.9077 - val_loss: 0.2545 - learning_rate: 4.6314e-06
# Epoch 48/100
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 0s 948ms/step - accuracy: 0.9189 - loss: 0.2210
# Epoch 48: val_loss did not improve from 0.25451
# 342/342 ━━━━━━━━━━━━━━━━━━━━ 395s 1s/step - accuracy: 0.9189 - loss: 0.2209 - val_accuracy: 0.9068 - val_loss: 0.2545 - learning_rate: 4.2682e-06
# Epoch 48: early stopping
# Restoring model weights from the end of the best epoch: 43.
#
# Restoring best weights for VGG19
# Total training time: 18888.93 seconds

# %%
#Best Validation Accuracy
best_val_acc = max(history.history['val_accuracy'])
print(f"Best validation Accuracy: {best_val_acc}")
# Out:
# Best validation Accuracy: 0.9085469841957092

# %%
# accuracies
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
# loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# evaluate the network
print("Evaluating network...")
predictions = model.predict(X_test)
preds = predictions > 0.5
# Out:
# Evaluating network...
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 68s 922ms/step

# %%
from collections import Counter
# Get predicted class distribution
predicted_classes = preds.astype(int).flatten()
class_counts = Counter(predicted_classes)

# Plot the class distribution
sns.barplot(x=list(class_counts.keys()), y=list(class_counts.values()), palette="muted")
plt.xticks([0, 1], ['NonViolence', 'Violence'])
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Predicted Class Distribution')
plt.show()
# Out:
# C:\Users\iamid\AppData\Local\Temp\ipykernel_13628\640220170.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(class_counts.keys()), y=list(class_counts.values()), palette="muted")

# %%
# Compute the confusion matrix
corr_pred = confusion_matrix(y_test, preds)

n_correct = int(corr_pred[0][0] + corr_pred[1][1])  # Count of correct predictions
print('> Correct Predictions:', n_correct)

n_wrongs = int(corr_pred[0][1] + corr_pred[1][0])  # Count of wrong predictions
print('> Wrong Predictions:', n_wrongs)

# Plot the confusion matrix using seaborn's heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_pred, annot=True, fmt="d", cmap="Blues", 
            xticklabels=["NonViolence", "Violence"], 
            yticklabels=["NonViolence", "Violence"])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()  # Ensure to call plt.show() to display the plot

# Print the classification report
print(metrics.classification_report(y_test, preds, 
                                     target_names=["NonViolence", "Violence"]))
# Out:
# > Correct Predictions: 1726
# > Wrong Predictions: 614
#               precision    recall  f1-score   support
#
#  NonViolence       0.82      0.56      0.67      1094
#     Violence       0.70      0.89      0.78      1246
#
#     accuracy                           0.74      2340
#    macro avg       0.76      0.73      0.72      2340
# weighted avg       0.76      0.74      0.73      2340

# %%
args_model = "Violence Detection VGG19.h5"
model.save(args_model)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model = load_model("Violence Detection VGG19.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Function to preprocess each frame
def preprocess_frame(frame, img_size=128):
    # Convert BGR to RGB
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    # Resize frame to match model's input size
    frame = cv2.resize(frame, (img_size, img_size))
    # Normalize pixel values
    frame = frame / 255.0
    # Expand dimensions to match model's input shape (1, 128, 128, 3)
    frame = np.expand_dims(frame, axis=0)
    return frame

# %%
# Function to predict and display frames with labels in real-time
def display_predictions_in_video(video_path):
    cap = cv2.VideoCapture(video_path)
    cap.set(3, 500)  # Set width
    cap.set(4, 450)   # Set height
    violent_frames = []  # List to store frames with violence detected
    
    # Check if the video opened successfully
    if not cap.isOpened():
        print("Error: Could not open video.")
        return
        
    
    frame_count = 0  # Counter to track the frames

    while cap.isOpened():
        success, frame = cap.read()
        
        if success:
            # Only process every 7th frame
            if frame_count % 7 == 0:
                # Preprocess the frame (resize, normalise, etc.)
                processed_frame = preprocess_frame(frame)

                # Predict using the model
                prediction = model.predict(processed_frame)

                # Determine label and corresponding color based on prediction
                if prediction >= 0.8:
                    label = "Violence"
                    color = (0, 0, 255)  # Red in BGR
                    violent_frames.append(frame)
                    
                else:
                    label = "NonViolence"
                    color = (0, 255, 0)  # Green in BGR
                print(f"- Prediction: {label}")

                # Overlay the label on the frame
                label_text = f"Prediction: {label}"
                cv2.putText(frame, label_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, color, 2)

                # Display the frame with the label
                cv2.imshow("Video Prediction", frame)

            frame_count += 1  # Increment the frame counter

            # Press 'q' to quit early
            if cv2.waitKey(30) & 0xFF == ord('q'):
                break
        else:
            print("End of video or read failure.")
            break  # Stop if the video has ended

    cap.release()
    cv2.destroyAllWindows()
    return violent_frames

# %%
def display_stored_violence_frames(violence_frames, rows=6, cols=6):
    num_frames = len(violence_frames)
    fig, axes = plt.subplots(rows, cols, figsize=(cols * 4, rows * 3))
    axes = axes.flatten()  # Flatten the 2D axes array for easier iteration

    for i, ax in enumerate(axes):
        if i < num_frames:
            # Convert BGR to RGB for displaying in Matplotlib
            frame_rgb = cv2.cvtColor(violence_frames[i], cv2.COLOR_BGR2RGB)
            ax.imshow(frame_rgb)
            ax.set_title(f"Frame {i+1}")
            ax.axis("off")  # Hide axes
        else:
            ax.axis("off")  # Hide any unused subplot spaces

    plt.tight_layout()
    plt.show()

# %%
# Test on an unseen video
video_path =  "9.mp4"  # Replace with the video file path
violent_frames = display_predictions_in_video(video_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# - Prediction: Violence
# End of video or read failure.

# %%
# Display stored violence-detected frames
if violent_frames:
    print(f"Number of violence-detected frames: {len(violent_frames)}")
    display_stored_violence_frames(violent_frames)
else:
    print("No violence-detected frames were stored.")
# Out:
# Number of violence-detected frames: 25
