# %%
import cv2
import os
import tensorflow as tf
import platform
import numpy as np
import random
import imageio
import imgaug.augmenters as iaa
import imgaug as ia
import matplotlib.pyplot as plt
import pickle
import datetime
import time
import seaborn as sns
import matplotlib
from keras import regularizers
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import StratifiedShuffleSplit
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Flatten, Conv2D, MaxPooling2D, TimeDistributed, Dropout
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import Callback, ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping, ReduceLROnPlateau
from keras.models import Model
from IPython.display import clear_output
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.models import load_model

# %%
IMG_SIZE = 128
ColorChannels = 3

# %%
def video_to_frames(video):
    cap = cv2.VideoCapture(video)  # Open the video file for reading frames
    
    frames_list = []  # List to store the processed image frames
    while cap.isOpened():  # Loop until the video has been completely processed
        ID = cap.get(1)  # Get the current frame ID (1 corresponds to the frame number)
        success, image = cap.read()  # Read the next frame from the video

        if success:  # If the frame was read successfully
            # Skip frames to avoid duplications; process every 4th frame
            if (ID % 7 == 0):  
                # Define image augmentations
                flip = iaa.Fliplr(1.0)  # Always flip the image horizontally (left to right)
                zoom = iaa.Affine(scale=1.3)  # Zoom the image by 30%
                random_brightness = iaa.Multiply((1, 1.3))  # Adjust brightness randomly (between 100% and 130%)
                rotate = iaa.Affine(rotate=(-25, 25))  # Rotate the image randomly between -25 and 25 degrees

                # Apply augmentations in sequence
                aug = flip(image=image)  # Apply horizontal flip
                aug = random_brightness(image= aug)  # Adjust brightness
                aug = zoom(image= aug)  # Apply zoom
                aug = rotate(image= aug)  # Apply rotation
                
                # Convert the augmented image from BGR (OpenCV format) to RGB (common format)
                to_rgb = cv2.cvtColor(aug, cv2.COLOR_BGR2RGB)
                # Resize the image to the specified dimensions
                resized = cv2.resize(to_rgb, (IMG_SIZE, IMG_SIZE))
                frames_list.append(resized)  # Add the resized image to the list of frames
                
            
        else:
            break  
    
    cap.release()  # Release the video capture object
    
    return frames_list  # Return the list of processed image frames

# %%
VideoData = 'Test Dataset'  # 'Train' folder contains  each class ("NonViolence" and "Violence")


X  = [] # List to store frames (image data) extracted from videos
y  = [] # List to store labels corresponding to each frame


classes = ["NonViolence", "Violence"]   # Classes: NonViolence = 0, Violence = 1

# Loop through each class folder in the 'Train' directory
for category in os.listdir(VideoData): 
    path = os.path.join(VideoData, category)  
    class_num = classes.index(category)       # Get the numeric label for the current category (0 or 1)

    # Loop through each video in the current category folder
    for i, video in enumerate(os.listdir(path)): 
        frames = video_to_frames(path + '/' + video)  # Extract frames from the video using the video_to_frames function
        
        # Loop through each frame extracted from the video
        for j, frame in enumerate(frames): 
            X.append(frame)                    
            y.append(class_num)

# %%
# Convert the lists of frames and labels into NumPy arrays
X = np.array(X)
y = np.array(y)                                       

print(len(X))
# Out:
# 15598

# %%
# First split - Train (70%) vs Temp (30%)
stratified = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=73)

for train_index, temp_index in stratified.split(X, y):
    X_train, X_temp = X[train_index], X[temp_index]
    y_train, y_temp = y[train_index], y[temp_index]

# Second split - Temp (15%) into Validation (50% of Temp) and Test (50% of Temp)
stratified1 = StratifiedShuffleSplit(n_splits=1, test_size=0.5, random_state=73)

for val_index, test_index in stratified1.split(X_temp, y_temp):
    X_val, X_test = X_temp[val_index], X_temp[test_index]
    y_val, y_test = y_temp[val_index], y_temp[test_index]

# %%
# / 255 normalizes pixel values to the range [0, 1] for better training performance
X_train_norm = X_train/ 255
X_test_norm = X_test/ 255
X_val_norm = X_val / 255

# %%
print("Training set shape:", X_train_norm.shape, y_train.shape)
print("Validation set shape:", X_val_norm.shape, y_val.shape)
print("Test set shape:", X_test_norm.shape, y_test.shape)
# Out:
# Training set shape: (10918, 128, 128, 3) (10918,)
# Validation set shape: (2340, 128, 128, 3) (2340,)
# Test set shape: (2340, 128, 128, 3) (2340,)

# %%
# L2 regularization with a strength of 0.0001 to prevent overfitting
kernel_regularizer = regularizers.l2(0.0001)  

# Create the base model using MobileNetV2 without the top layers
baseModel = MobileNetV2(pooling='avg', 
                        include_top=False, 
                        input_shape=(IMG_SIZE,IMG_SIZE,ColorChannels) )  

# Freeze the layers of the base model to prevent them from being updated during training
for layer in baseModel.layers:
    layer.trainable = False  
    
# Get the output from the base model
modelTop = baseModel.output  

# Add a dense layer with 1 output unit for binary classification, using sigmoid activation
modelTop = Dense(1, activation="sigmoid",kernel_regularizer=kernel_regularizer)(modelTop)  

# Create the full model by specifying the inputs and outputs
model = Model(inputs=baseModel.input, outputs=modelTop)  


# Print a message indicating that the model is being compiled
print("Compiling model...")  

# Compile the model with binary crossentropy loss, Adam optimizer, and accuracy as the evaluation metric
model.compile(loss="binary_crossentropy", 
              optimizer='adam', 
              metrics=["accuracy"])  

# Print a summary of the model architecture, including layer types and output shapes
model.summary()
# Out:
# Compiling model...
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 64, 64,    │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 64, 64,    │        128 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1_relu (ReLU)   │ (None, 64, 64,    │          0 │ bn_Conv1[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 64, 64,    │        288 │ Conv1_relu[0][0]  │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 64, 64,    │        128 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 64, 64,    │          0 │ expanded_conv_de… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 64, 64,    │        512 │ expanded_conv_de… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 64, 64,    │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand      │ (None, 64, 64,    │      1,536 │ expanded_conv_pr… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_BN   │ (None, 64, 64,    │        384 │ block_1_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_relu │ (None, 64, 64,    │          0 │ block_1_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_pad         │ (None, 65, 65,    │          0 │ block_1_expand_r… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise   │ (None, 32, 32,    │        864 │ block_1_pad[0][0] │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 32, 32,    │        384 │ block_1_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 32, 32,    │          0 │ block_1_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project     │ (None, 32, 32,    │      2,304 │ block_1_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project_BN  │ (None, 32, 32,    │         96 │ block_1_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand      │ (None, 32, 32,    │      3,456 │ block_1_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_BN   │ (None, 32, 32,    │        576 │ block_2_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_relu │ (None, 32, 32,    │          0 │ block_2_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise   │ (None, 32, 32,    │      1,296 │ block_2_expand_r… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 32, 32,    │        576 │ block_2_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 32, 32,    │          0 │ block_2_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project     │ (None, 32, 32,    │      3,456 │ block_2_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project_BN  │ (None, 32, 32,    │         96 │ block_2_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_add (Add)   │ (None, 32, 32,    │          0 │ block_1_project_… │
# │                     │ 24)               │            │ block_2_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand      │ (None, 32, 32,    │      3,456 │ block_2_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_BN   │ (None, 32, 32,    │        576 │ block_3_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_relu │ (None, 32, 32,    │          0 │ block_3_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_pad         │ (None, 33, 33,    │          0 │ block_3_expand_r… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise   │ (None, 16, 16,    │      1,296 │ block_3_pad[0][0] │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 16, 16,    │        576 │ block_3_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 16, 16,    │          0 │ block_3_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project     │ (None, 16, 16,    │      4,608 │ block_3_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project_BN  │ (None, 16, 16,    │        128 │ block_3_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand      │ (None, 16, 16,    │      6,144 │ block_3_project_… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_BN   │ (None, 16, 16,    │        768 │ block_4_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_relu │ (None, 16, 16,    │          0 │ block_4_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise   │ (None, 16, 16,    │      1,728 │ block_4_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 16, 16,    │        768 │ block_4_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 16, 16,    │          0 │ block_4_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project     │ (None, 16, 16,    │      6,144 │ block_4_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project_BN  │ (None, 16, 16,    │        128 │ block_4_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_add (Add)   │ (None, 16, 16,    │          0 │ block_3_project_… │
# │                     │ 32)               │            │ block_4_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand      │ (None, 16, 16,    │      6,144 │ block_4_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_BN   │ (None, 16, 16,    │        768 │ block_5_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_relu │ (None, 16, 16,    │          0 │ block_5_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise   │ (None, 16, 16,    │      1,728 │ block_5_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 16, 16,    │        768 │ block_5_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 16, 16,    │          0 │ block_5_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project     │ (None, 16, 16,    │      6,144 │ block_5_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project_BN  │ (None, 16, 16,    │        128 │ block_5_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_add (Add)   │ (None, 16, 16,    │          0 │ block_4_add[0][0… │
# │                     │ 32)               │            │ block_5_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand      │ (None, 16, 16,    │      6,144 │ block_5_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_BN   │ (None, 16, 16,    │        768 │ block_6_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_relu │ (None, 16, 16,    │          0 │ block_6_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_pad         │ (None, 17, 17,    │          0 │ block_6_expand_r… │
# │ (ZeroPadding2D)     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise   │ (None, 8, 8, 192) │      1,728 │ block_6_pad[0][0] │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 8, 8, 192) │        768 │ block_6_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 8, 8, 192) │          0 │ block_6_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project     │ (None, 8, 8, 64)  │     12,288 │ block_6_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project_BN  │ (None, 8, 8, 64)  │        256 │ block_6_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand      │ (None, 8, 8, 384) │     24,576 │ block_6_project_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_BN   │ (None, 8, 8, 384) │      1,536 │ block_7_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_relu │ (None, 8, 8, 384) │          0 │ block_7_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise   │ (None, 8, 8, 384) │      3,456 │ block_7_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 8, 8, 384) │      1,536 │ block_7_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 8, 8, 384) │          0 │ block_7_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project     │ (None, 8, 8, 64)  │     24,576 │ block_7_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project_BN  │ (None, 8, 8, 64)  │        256 │ block_7_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_add (Add)   │ (None, 8, 8, 64)  │          0 │ block_6_project_… │
# │                     │                   │            │ block_7_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand      │ (None, 8, 8, 384) │     24,576 │ block_7_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_BN   │ (None, 8, 8, 384) │      1,536 │ block_8_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_relu │ (None, 8, 8, 384) │          0 │ block_8_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise   │ (None, 8, 8, 384) │      3,456 │ block_8_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 8, 8, 384) │      1,536 │ block_8_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 8, 8, 384) │          0 │ block_8_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project     │ (None, 8, 8, 64)  │     24,576 │ block_8_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project_BN  │ (None, 8, 8, 64)  │        256 │ block_8_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_add (Add)   │ (None, 8, 8, 64)  │          0 │ block_7_add[0][0… │
# │                     │                   │            │ block_8_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand      │ (None, 8, 8, 384) │     24,576 │ block_8_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_BN   │ (None, 8, 8, 384) │      1,536 │ block_9_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_relu │ (None, 8, 8, 384) │          0 │ block_9_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise   │ (None, 8, 8, 384) │      3,456 │ block_9_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 8, 8, 384) │      1,536 │ block_9_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 8, 8, 384) │          0 │ block_9_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project     │ (None, 8, 8, 64)  │     24,576 │ block_9_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project_BN  │ (None, 8, 8, 64)  │        256 │ block_9_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_add (Add)   │ (None, 8, 8, 64)  │          0 │ block_8_add[0][0… │
# │                     │                   │            │ block_9_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand     │ (None, 8, 8, 384) │     24,576 │ block_9_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_BN  │ (None, 8, 8, 384) │      1,536 │ block_10_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_re… │ (None, 8, 8, 384) │          0 │ block_10_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise  │ (None, 8, 8, 384) │      3,456 │ block_10_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 8, 8, 384) │      1,536 │ block_10_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 8, 8, 384) │          0 │ block_10_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project    │ (None, 8, 8, 96)  │     36,864 │ block_10_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project_BN │ (None, 8, 8, 96)  │        384 │ block_10_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand     │ (None, 8, 8, 576) │     55,296 │ block_10_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_BN  │ (None, 8, 8, 576) │      2,304 │ block_11_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_re… │ (None, 8, 8, 576) │          0 │ block_11_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise  │ (None, 8, 8, 576) │      5,184 │ block_11_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 8, 8, 576) │      2,304 │ block_11_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 8, 8, 576) │          0 │ block_11_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project    │ (None, 8, 8, 96)  │     55,296 │ block_11_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project_BN │ (None, 8, 8, 96)  │        384 │ block_11_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_add (Add)  │ (None, 8, 8, 96)  │          0 │ block_10_project… │
# │                     │                   │            │ block_11_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand     │ (None, 8, 8, 576) │     55,296 │ block_11_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_BN  │ (None, 8, 8, 576) │      2,304 │ block_12_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_re… │ (None, 8, 8, 576) │          0 │ block_12_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise  │ (None, 8, 8, 576) │      5,184 │ block_12_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 8, 8, 576) │      2,304 │ block_12_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 8, 8, 576) │          0 │ block_12_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project    │ (None, 8, 8, 96)  │     55,296 │ block_12_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project_BN │ (None, 8, 8, 96)  │        384 │ block_12_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_add (Add)  │ (None, 8, 8, 96)  │          0 │ block_11_add[0][… │
# │                     │                   │            │ block_12_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand     │ (None, 8, 8, 576) │     55,296 │ block_12_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_BN  │ (None, 8, 8, 576) │      2,304 │ block_13_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_re… │ (None, 8, 8, 576) │          0 │ block_13_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_pad        │ (None, 9, 9, 576) │          0 │ block_13_expand_… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise  │ (None, 4, 4, 576) │      5,184 │ block_13_pad[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 4, 4, 576) │      2,304 │ block_13_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 4, 4, 576) │          0 │ block_13_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project    │ (None, 4, 4, 160) │     92,160 │ block_13_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project_BN │ (None, 4, 4, 160) │        640 │ block_13_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand     │ (None, 4, 4, 960) │    153,600 │ block_13_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_BN  │ (None, 4, 4, 960) │      3,840 │ block_14_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_re… │ (None, 4, 4, 960) │          0 │ block_14_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise  │ (None, 4, 4, 960) │      8,640 │ block_14_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 4, 4, 960) │      3,840 │ block_14_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 4, 4, 960) │          0 │ block_14_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project    │ (None, 4, 4, 160) │    153,600 │ block_14_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project_BN │ (None, 4, 4, 160) │        640 │ block_14_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_add (Add)  │ (None, 4, 4, 160) │          0 │ block_13_project… │
# │                     │                   │            │ block_14_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand     │ (None, 4, 4, 960) │    153,600 │ block_14_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_BN  │ (None, 4, 4, 960) │      3,840 │ block_15_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_re… │ (None, 4, 4, 960) │          0 │ block_15_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise  │ (None, 4, 4, 960) │      8,640 │ block_15_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 4, 4, 960) │      3,840 │ block_15_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 4, 4, 960) │          0 │ block_15_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project    │ (None, 4, 4, 160) │    153,600 │ block_15_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project_BN │ (None, 4, 4, 160) │        640 │ block_15_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_add (Add)  │ (None, 4, 4, 160) │          0 │ block_14_add[0][… │
# │                     │                   │            │ block_15_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand     │ (None, 4, 4, 960) │    153,600 │ block_15_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_BN  │ (None, 4, 4, 960) │      3,840 │ block_16_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_re… │ (None, 4, 4, 960) │          0 │ block_16_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise  │ (None, 4, 4, 960) │      8,640 │ block_16_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 4, 4, 960) │      3,840 │ block_16_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 4, 4, 960) │          0 │ block_16_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project    │ (None, 4, 4, 320) │    307,200 │ block_16_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project_BN │ (None, 4, 4, 320) │      1,280 │ block_16_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1 (Conv2D)     │ (None, 4, 4,      │    409,600 │ block_16_project… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1_bn           │ (None, 4, 4,      │      5,120 │ Conv_1[0][0]      │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_relu (ReLU)     │ (None, 4, 4,      │          0 │ Conv_1_bn[0][0]   │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ out_relu[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1)         │      1,281 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,259,265 (8.62 MB)
#  Trainable params: 1,281 (5.00 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
# Define parameters for learning rate scheduling and early stopping
epochs = 100
patience = 5
start_lr = 1e-5
max_lr = 5e-5
min_lr = 1e-5

batch_size = 16

rampup_epochs = 5  # Number of epochs to ramp up learning rate
sustain_epochs = 0  # Number of epochs to sustain the maximum learning rate
exp_decay = .8  # Exponential decay factor for the learning rate


def lrfn(epoch):
    if epoch < rampup_epochs:
        return (max_lr - start_lr) / rampup_epochs * epoch + start_lr
    elif epoch < rampup_epochs + sustain_epochs:
        return max_lr
    else:
        return (max_lr - min_lr) * exp_decay ** (epoch - rampup_epochs - sustain_epochs) + min_lr

class myCallback(Callback):
    def on_epoch_end(self, epoch, logs={}):
        if logs.get('accuracy') >= 0.999:
            print("\nLimits Reached, cancelling training!")
            self.model.stop_training = True


end_callback = myCallback()

lr_callback = LearningRateScheduler(lambda epoch: lrfn(epoch), verbose=False)

early_stopping = EarlyStopping(patience = patience, monitor='val_loss',
                                 mode='min', restore_best_weights=True,
                                 verbose = 1, min_delta = .00075)


lr_plat = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=patience, min_lr=1e-7)

os.system('rm -rf ./logs/')


log_dir="logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir = log_dir, write_graph=True, histogram_freq=1)

checkpoint_filepath = 'MobileNetV2ModelWeights.weights.h5'

model_checkpoints = ModelCheckpoint(filepath=checkpoint_filepath,
                                        save_weights_only=True,
                                        monitor='val_loss',
                                        mode='min',
                                        verbose = 1,
                                        save_best_only=True)


callbacks = [end_callback, lr_callback, model_checkpoints, tensorboard_callback, early_stopping, lr_plat]

# %%
# Training the model head 
print('Training head...')

# Start the timer before training
start_time = time.time()

history = model.fit(
    X_train_norm,                   # Training data normalized for input to the model.
    y_train,                        # Corresponding labels for the training data.
    epochs=epochs,                  # Number of epochs to train the model.
    callbacks=callbacks,            # List of callbacks to apply during training (like early stopping, learning rate adjustments).
    validation_data=(X_val_norm, y_val),  # Validation data and labels for evaluating model performance during training.
    batch_size=batch_size           # Number of samples per gradient update.
)
# End the timer after training
end_time = time.time()

# Notify the user that the best weights are being restored after training is complete.
print('\nRestoring best weights for MobileNetV2')

# Calculate the total training time
training_time = end_time - start_time
print(f"Total training time: {training_time:.2f} seconds")

# Load the best model weights that were saved during training based on the validation loss.
model.load_weights(checkpoint_filepath)
# Out:
# Training head...
# Epoch 1/100
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6298 - loss: 0.6727
# Epoch 1: val_loss improved from inf to 0.58750, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 80s 109ms/step - accuracy: 0.6298 - loss: 0.6727 - val_accuracy: 0.6855 - val_loss: 0.5875 - learning_rate: 1.0000e-05
# Epoch 2/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7192 - loss: 0.5573
# Epoch 2: val_loss improved from 0.58750 to 0.47682, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 71s 104ms/step - accuracy: 0.7192 - loss: 0.5572 - val_accuracy: 0.7607 - val_loss: 0.4768 - learning_rate: 1.8000e-05
# Epoch 3/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7827 - loss: 0.4528
# Epoch 3: val_loss improved from 0.47682 to 0.39209, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 77s 113ms/step - accuracy: 0.7828 - loss: 0.4527 - val_accuracy: 0.8248 - val_loss: 0.3921 - learning_rate: 2.6000e-05
# Epoch 4/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8438 - loss: 0.3696
# Epoch 4: val_loss improved from 0.39209 to 0.33344, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 70s 102ms/step - accuracy: 0.8438 - loss: 0.3696 - val_accuracy: 0.8551 - val_loss: 0.3334 - learning_rate: 3.4000e-05
# Epoch 5/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8735 - loss: 0.3106
# Epoch 5: val_loss improved from 0.33344 to 0.29473, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 70s 102ms/step - accuracy: 0.8735 - loss: 0.3106 - val_accuracy: 0.8799 - val_loss: 0.2947 - learning_rate: 4.2000e-05
# Epoch 6/100
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8904 - loss: 0.2792
# Epoch 6: val_loss improved from 0.29473 to 0.26637, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 71s 104ms/step - accuracy: 0.8904 - loss: 0.2791 - val_accuracy: 0.8936 - val_loss: 0.2664 - learning_rate: 5.0000e-05
# Epoch 7/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9016 - loss: 0.2495
# Epoch 7: val_loss improved from 0.26637 to 0.25007, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 74s 108ms/step - accuracy: 0.9016 - loss: 0.2496 - val_accuracy: 0.8991 - val_loss: 0.2501 - learning_rate: 4.2000e-05
# Epoch 8/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9070 - loss: 0.2414
# Epoch 8: val_loss improved from 0.25007 to 0.23980, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 71s 104ms/step - accuracy: 0.9070 - loss: 0.2414 - val_accuracy: 0.9064 - val_loss: 0.2398 - learning_rate: 3.5600e-05
# Epoch 9/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9096 - loss: 0.2302
# Epoch 9: val_loss improved from 0.23980 to 0.23250, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 71s 104ms/step - accuracy: 0.9096 - loss: 0.2302 - val_accuracy: 0.9085 - val_loss: 0.2325 - learning_rate: 3.0480e-05
# Epoch 10/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9125 - loss: 0.2230
# Epoch 10: val_loss improved from 0.23250 to 0.22729, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 71s 104ms/step - accuracy: 0.9125 - loss: 0.2230 - val_accuracy: 0.9115 - val_loss: 0.2273 - learning_rate: 2.6384e-05
# Epoch 11/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9173 - loss: 0.2133
# Epoch 11: val_loss improved from 0.22729 to 0.22269, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 72s 105ms/step - accuracy: 0.9173 - loss: 0.2133 - val_accuracy: 0.9124 - val_loss: 0.2227 - learning_rate: 2.3107e-05
# Epoch 12/100
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9205 - loss: 0.2072
# Epoch 12: val_loss improved from 0.22269 to 0.21932, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 74s 108ms/step - accuracy: 0.9204 - loss: 0.2072 - val_accuracy: 0.9150 - val_loss: 0.2193 - learning_rate: 2.0486e-05
# Epoch 13/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9216 - loss: 0.2060
# Epoch 13: val_loss improved from 0.21932 to 0.21641, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 73s 107ms/step - accuracy: 0.9215 - loss: 0.2060 - val_accuracy: 0.9132 - val_loss: 0.2164 - learning_rate: 1.8389e-05
# Epoch 14/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9221 - loss: 0.1996
# Epoch 14: val_loss improved from 0.21641 to 0.21415, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 72s 105ms/step - accuracy: 0.9221 - loss: 0.1996 - val_accuracy: 0.9171 - val_loss: 0.2141 - learning_rate: 1.6711e-05
# Epoch 15/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9204 - loss: 0.2077
# Epoch 15: val_loss improved from 0.21415 to 0.21200, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 73s 106ms/step - accuracy: 0.9204 - loss: 0.2077 - val_accuracy: 0.9179 - val_loss: 0.2120 - learning_rate: 1.5369e-05
# Epoch 16/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9193 - loss: 0.2056
# Epoch 16: val_loss improved from 0.21200 to 0.21009, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 72s 106ms/step - accuracy: 0.9193 - loss: 0.2056 - val_accuracy: 0.9192 - val_loss: 0.2101 - learning_rate: 1.4295e-05
# Epoch 17/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9207 - loss: 0.2034
# Epoch 17: val_loss improved from 0.21009 to 0.20837, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 73s 106ms/step - accuracy: 0.9207 - loss: 0.2034 - val_accuracy: 0.9205 - val_loss: 0.2084 - learning_rate: 1.3436e-05
# Epoch 18/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9248 - loss: 0.1986
# Epoch 18: val_loss improved from 0.20837 to 0.20698, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 76s 112ms/step - accuracy: 0.9248 - loss: 0.1986 - val_accuracy: 0.9218 - val_loss: 0.2070 - learning_rate: 1.2749e-05
# Epoch 19/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9262 - loss: 0.1962
# Epoch 19: val_loss improved from 0.20698 to 0.20558, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 74s 108ms/step - accuracy: 0.9262 - loss: 0.1962 - val_accuracy: 0.9226 - val_loss: 0.2056 - learning_rate: 1.2199e-05
# Epoch 20/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9258 - loss: 0.1933
# Epoch 20: val_loss improved from 0.20558 to 0.20435, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 73s 107ms/step - accuracy: 0.9258 - loss: 0.1933 - val_accuracy: 0.9226 - val_loss: 0.2043 - learning_rate: 1.1759e-05
# Epoch 21/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9255 - loss: 0.1957
# Epoch 21: val_loss improved from 0.20435 to 0.20309, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 73s 107ms/step - accuracy: 0.9255 - loss: 0.1957 - val_accuracy: 0.9235 - val_loss: 0.2031 - learning_rate: 1.1407e-05
# Epoch 22/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9297 - loss: 0.1929
# Epoch 22: val_loss improved from 0.20309 to 0.20188, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 73s 106ms/step - accuracy: 0.9297 - loss: 0.1929 - val_accuracy: 0.9244 - val_loss: 0.2019 - learning_rate: 1.1126e-05
# Epoch 23/100
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9277 - loss: 0.1888
# Epoch 23: val_loss improved from 0.20188 to 0.20078, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 73s 107ms/step - accuracy: 0.9277 - loss: 0.1888 - val_accuracy: 0.9244 - val_loss: 0.2008 - learning_rate: 1.0901e-05
# Epoch 24/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9314 - loss: 0.1828
# Epoch 24: val_loss improved from 0.20078 to 0.19969, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 73s 106ms/step - accuracy: 0.9314 - loss: 0.1828 - val_accuracy: 0.9252 - val_loss: 0.1997 - learning_rate: 1.0721e-05
# Epoch 25/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9294 - loss: 0.1838
# Epoch 25: val_loss improved from 0.19969 to 0.19874, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 74s 109ms/step - accuracy: 0.9294 - loss: 0.1838 - val_accuracy: 0.9256 - val_loss: 0.1987 - learning_rate: 1.0576e-05
# Epoch 26/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9280 - loss: 0.1886
# Epoch 26: val_loss improved from 0.19874 to 0.19777, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 73s 107ms/step - accuracy: 0.9280 - loss: 0.1886 - val_accuracy: 0.9256 - val_loss: 0.1978 - learning_rate: 1.0461e-05
# Epoch 27/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9276 - loss: 0.1895
# Epoch 27: val_loss improved from 0.19777 to 0.19689, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 74s 108ms/step - accuracy: 0.9276 - loss: 0.1895 - val_accuracy: 0.9269 - val_loss: 0.1969 - learning_rate: 1.0369e-05
# Epoch 28/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9305 - loss: 0.1800
# Epoch 28: val_loss improved from 0.19689 to 0.19596, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 68s 99ms/step - accuracy: 0.9305 - loss: 0.1800 - val_accuracy: 0.9274 - val_loss: 0.1960 - learning_rate: 1.0295e-05
# Epoch 29/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9300 - loss: 0.1809
# Epoch 29: val_loss improved from 0.19596 to 0.19549, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 69s 102ms/step - accuracy: 0.9300 - loss: 0.1809 - val_accuracy: 0.9286 - val_loss: 0.1955 - learning_rate: 1.0236e-05
# Epoch 30/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9333 - loss: 0.1809
# Epoch 30: val_loss improved from 0.19549 to 0.19437, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 79s 115ms/step - accuracy: 0.9333 - loss: 0.1809 - val_accuracy: 0.9278 - val_loss: 0.1944 - learning_rate: 1.0189e-05
# Epoch 31/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9322 - loss: 0.1798
# Epoch 31: val_loss improved from 0.19437 to 0.19362, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 67s 98ms/step - accuracy: 0.9322 - loss: 0.1798 - val_accuracy: 0.9295 - val_loss: 0.1936 - learning_rate: 1.0151e-05
# Epoch 32/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9341 - loss: 0.1773
# Epoch 32: val_loss improved from 0.19362 to 0.19272, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 67s 99ms/step - accuracy: 0.9341 - loss: 0.1773 - val_accuracy: 0.9291 - val_loss: 0.1927 - learning_rate: 1.0121e-05
# Epoch 33/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9356 - loss: 0.1737
# Epoch 33: val_loss improved from 0.19272 to 0.19192, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 68s 100ms/step - accuracy: 0.9356 - loss: 0.1737 - val_accuracy: 0.9303 - val_loss: 0.1919 - learning_rate: 1.0097e-05
# Epoch 34/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9294 - loss: 0.1872
# Epoch 34: val_loss improved from 0.19192 to 0.19132, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 74s 108ms/step - accuracy: 0.9294 - loss: 0.1872 - val_accuracy: 0.9308 - val_loss: 0.1913 - learning_rate: 1.0077e-05
# Epoch 35/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9326 - loss: 0.1786
# Epoch 35: val_loss improved from 0.19132 to 0.19042, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 73s 107ms/step - accuracy: 0.9326 - loss: 0.1786 - val_accuracy: 0.9312 - val_loss: 0.1904 - learning_rate: 1.0062e-05
# Epoch 36/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9337 - loss: 0.1755
# Epoch 36: val_loss improved from 0.19042 to 0.18973, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 73s 107ms/step - accuracy: 0.9337 - loss: 0.1755 - val_accuracy: 0.9321 - val_loss: 0.1897 - learning_rate: 1.0050e-05
# Epoch 37/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9406 - loss: 0.1714
# Epoch 37: val_loss improved from 0.18973 to 0.18920, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 73s 106ms/step - accuracy: 0.9406 - loss: 0.1714 - val_accuracy: 0.9325 - val_loss: 0.1892 - learning_rate: 1.0040e-05
# Epoch 38/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9383 - loss: 0.1715
# Epoch 38: val_loss improved from 0.18920 to 0.18835, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 72s 106ms/step - accuracy: 0.9383 - loss: 0.1715 - val_accuracy: 0.9321 - val_loss: 0.1884 - learning_rate: 1.0032e-05
# Epoch 39/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9377 - loss: 0.1716
# Epoch 39: val_loss improved from 0.18835 to 0.18775, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 71s 104ms/step - accuracy: 0.9377 - loss: 0.1716 - val_accuracy: 0.9338 - val_loss: 0.1878 - learning_rate: 1.0025e-05
# Epoch 40/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9363 - loss: 0.1755
# Epoch 40: val_loss improved from 0.18775 to 0.18715, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 72s 106ms/step - accuracy: 0.9363 - loss: 0.1755 - val_accuracy: 0.9338 - val_loss: 0.1871 - learning_rate: 1.0020e-05
# Epoch 41/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9363 - loss: 0.1709
# Epoch 41: val_loss improved from 0.18715 to 0.18640, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 75s 110ms/step - accuracy: 0.9363 - loss: 0.1709 - val_accuracy: 0.9338 - val_loss: 0.1864 - learning_rate: 1.0016e-05
# Epoch 42/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9384 - loss: 0.1684
# Epoch 42: val_loss improved from 0.18640 to 0.18580, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 73s 106ms/step - accuracy: 0.9384 - loss: 0.1684 - val_accuracy: 0.9338 - val_loss: 0.1858 - learning_rate: 1.0013e-05
# Epoch 43/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9342 - loss: 0.1714
# Epoch 43: val_loss improved from 0.18580 to 0.18518, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 71s 103ms/step - accuracy: 0.9342 - loss: 0.1714 - val_accuracy: 0.9338 - val_loss: 0.1852 - learning_rate: 1.0010e-05
# Epoch 44/100
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9399 - loss: 0.1686
# Epoch 44: val_loss improved from 0.18518 to 0.18474, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 79s 116ms/step - accuracy: 0.9399 - loss: 0.1686 - val_accuracy: 0.9338 - val_loss: 0.1847 - learning_rate: 1.0008e-05
# Epoch 45/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9356 - loss: 0.1732
# Epoch 45: val_loss improved from 0.18474 to 0.18414, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 75s 110ms/step - accuracy: 0.9356 - loss: 0.1732 - val_accuracy: 0.9342 - val_loss: 0.1841 - learning_rate: 1.0007e-05
# Epoch 46/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9361 - loss: 0.1730
# Epoch 46: val_loss improved from 0.18414 to 0.18358, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 74s 109ms/step - accuracy: 0.9361 - loss: 0.1730 - val_accuracy: 0.9342 - val_loss: 0.1836 - learning_rate: 1.0005e-05
# Epoch 47/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9365 - loss: 0.1691
# Epoch 47: val_loss improved from 0.18358 to 0.18286, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 72s 106ms/step - accuracy: 0.9365 - loss: 0.1691 - val_accuracy: 0.9338 - val_loss: 0.1829 - learning_rate: 1.0004e-05
# Epoch 48/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9373 - loss: 0.1702
# Epoch 48: val_loss improved from 0.18286 to 0.18229, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 73s 107ms/step - accuracy: 0.9373 - loss: 0.1702 - val_accuracy: 0.9333 - val_loss: 0.1823 - learning_rate: 1.0003e-05
# Epoch 49/100
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9398 - loss: 0.1681
# Epoch 49: val_loss improved from 0.18229 to 0.18182, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 73s 107ms/step - accuracy: 0.9398 - loss: 0.1681 - val_accuracy: 0.9338 - val_loss: 0.1818 - learning_rate: 1.0003e-05
# Epoch 50/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9375 - loss: 0.1698
# Epoch 50: val_loss improved from 0.18182 to 0.18123, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 73s 108ms/step - accuracy: 0.9375 - loss: 0.1697 - val_accuracy: 0.9342 - val_loss: 0.1812 - learning_rate: 1.0002e-05
# Epoch 51/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9378 - loss: 0.1668
# Epoch 51: val_loss improved from 0.18123 to 0.18077, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 73s 107ms/step - accuracy: 0.9378 - loss: 0.1668 - val_accuracy: 0.9346 - val_loss: 0.1808 - learning_rate: 1.0002e-05
# Epoch 52/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9346 - loss: 0.1735
# Epoch 52: val_loss improved from 0.18077 to 0.18016, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 72s 105ms/step - accuracy: 0.9346 - loss: 0.1735 - val_accuracy: 0.9350 - val_loss: 0.1802 - learning_rate: 1.0001e-05
# Epoch 53/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9418 - loss: 0.1634
# Epoch 53: val_loss improved from 0.18016 to 0.17977, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 73s 107ms/step - accuracy: 0.9418 - loss: 0.1634 - val_accuracy: 0.9346 - val_loss: 0.1798 - learning_rate: 1.0001e-05
# Epoch 54/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9400 - loss: 0.1604
# Epoch 54: val_loss improved from 0.17977 to 0.17938, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 74s 108ms/step - accuracy: 0.9400 - loss: 0.1604 - val_accuracy: 0.9350 - val_loss: 0.1794 - learning_rate: 1.0001e-05
# Epoch 55/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9369 - loss: 0.1690
# Epoch 55: val_loss improved from 0.17938 to 0.17874, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 74s 108ms/step - accuracy: 0.9369 - loss: 0.1690 - val_accuracy: 0.9346 - val_loss: 0.1787 - learning_rate: 1.0001e-05
# Epoch 56/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9361 - loss: 0.1672
# Epoch 56: val_loss improved from 0.17874 to 0.17852, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 74s 108ms/step - accuracy: 0.9361 - loss: 0.1671 - val_accuracy: 0.9350 - val_loss: 0.1785 - learning_rate: 1.0001e-05
# Epoch 57/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9414 - loss: 0.1642
# Epoch 57: val_loss improved from 0.17852 to 0.17776, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 74s 109ms/step - accuracy: 0.9414 - loss: 0.1642 - val_accuracy: 0.9355 - val_loss: 0.1778 - learning_rate: 1.0000e-05
# Epoch 58/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9423 - loss: 0.1616
# Epoch 58: val_loss improved from 0.17776 to 0.17728, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 74s 109ms/step - accuracy: 0.9423 - loss: 0.1616 - val_accuracy: 0.9363 - val_loss: 0.1773 - learning_rate: 1.0000e-05
# Epoch 59/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9353 - loss: 0.1726
# Epoch 59: val_loss improved from 0.17728 to 0.17694, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 74s 108ms/step - accuracy: 0.9353 - loss: 0.1725 - val_accuracy: 0.9350 - val_loss: 0.1769 - learning_rate: 1.0000e-05
# Epoch 60/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9437 - loss: 0.1612
# Epoch 60: val_loss improved from 0.17694 to 0.17644, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 74s 109ms/step - accuracy: 0.9437 - loss: 0.1612 - val_accuracy: 0.9359 - val_loss: 0.1764 - learning_rate: 1.0000e-05
# Epoch 61/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9371 - loss: 0.1715
# Epoch 61: val_loss improved from 0.17644 to 0.17608, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 76s 111ms/step - accuracy: 0.9371 - loss: 0.1715 - val_accuracy: 0.9363 - val_loss: 0.1761 - learning_rate: 1.0000e-05
# Epoch 62/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9449 - loss: 0.1558
# Epoch 62: val_loss improved from 0.17608 to 0.17552, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 75s 110ms/step - accuracy: 0.9449 - loss: 0.1559 - val_accuracy: 0.9363 - val_loss: 0.1755 - learning_rate: 1.0000e-05
# Epoch 63/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9421 - loss: 0.1580
# Epoch 63: val_loss improved from 0.17552 to 0.17512, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 75s 110ms/step - accuracy: 0.9421 - loss: 0.1580 - val_accuracy: 0.9368 - val_loss: 0.1751 - learning_rate: 1.0000e-05
# Epoch 64/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9444 - loss: 0.1544
# Epoch 64: val_loss improved from 0.17512 to 0.17468, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 78s 114ms/step - accuracy: 0.9444 - loss: 0.1544 - val_accuracy: 0.9368 - val_loss: 0.1747 - learning_rate: 1.0000e-05
# Epoch 65/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9417 - loss: 0.1566
# Epoch 65: val_loss improved from 0.17468 to 0.17426, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 76s 111ms/step - accuracy: 0.9417 - loss: 0.1566 - val_accuracy: 0.9372 - val_loss: 0.1743 - learning_rate: 1.0000e-05
# Epoch 66/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9428 - loss: 0.1569
# Epoch 66: val_loss improved from 0.17426 to 0.17387, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 78s 114ms/step - accuracy: 0.9428 - loss: 0.1569 - val_accuracy: 0.9368 - val_loss: 0.1739 - learning_rate: 1.0000e-05
# Epoch 67/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9394 - loss: 0.1639
# Epoch 67: val_loss improved from 0.17387 to 0.17347, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 78s 114ms/step - accuracy: 0.9395 - loss: 0.1639 - val_accuracy: 0.9372 - val_loss: 0.1735 - learning_rate: 1.0000e-05
# Epoch 68/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9451 - loss: 0.1540
# Epoch 68: val_loss improved from 0.17347 to 0.17309, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 80s 117ms/step - accuracy: 0.9451 - loss: 0.1540 - val_accuracy: 0.9372 - val_loss: 0.1731 - learning_rate: 1.0000e-05
# Epoch 69/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9415 - loss: 0.1617
# Epoch 69: val_loss improved from 0.17309 to 0.17272, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 84s 123ms/step - accuracy: 0.9415 - loss: 0.1617 - val_accuracy: 0.9372 - val_loss: 0.1727 - learning_rate: 1.0000e-05
# Epoch 70/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9375 - loss: 0.1607
# Epoch 70: val_loss improved from 0.17272 to 0.17234, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 82s 120ms/step - accuracy: 0.9375 - loss: 0.1606 - val_accuracy: 0.9372 - val_loss: 0.1723 - learning_rate: 1.0000e-05
# Epoch 71/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9385 - loss: 0.1623
# Epoch 71: val_loss improved from 0.17234 to 0.17198, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 82s 120ms/step - accuracy: 0.9385 - loss: 0.1623 - val_accuracy: 0.9368 - val_loss: 0.1720 - learning_rate: 1.0000e-05
# Epoch 72/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9457 - loss: 0.1532
# Epoch 72: val_loss improved from 0.17198 to 0.17155, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 82s 120ms/step - accuracy: 0.9457 - loss: 0.1532 - val_accuracy: 0.9385 - val_loss: 0.1716 - learning_rate: 1.0000e-05
# Epoch 73/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9440 - loss: 0.1539
# Epoch 73: val_loss improved from 0.17155 to 0.17115, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 83s 121ms/step - accuracy: 0.9440 - loss: 0.1539 - val_accuracy: 0.9389 - val_loss: 0.1712 - learning_rate: 1.0000e-05
# Epoch 74/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9435 - loss: 0.1553
# Epoch 74: val_loss improved from 0.17115 to 0.17085, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 84s 124ms/step - accuracy: 0.9435 - loss: 0.1553 - val_accuracy: 0.9380 - val_loss: 0.1708 - learning_rate: 1.0000e-05
# Epoch 75/100
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9478 - loss: 0.1511
# Epoch 75: val_loss improved from 0.17085 to 0.17052, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 84s 122ms/step - accuracy: 0.9478 - loss: 0.1511 - val_accuracy: 0.9376 - val_loss: 0.1705 - learning_rate: 1.0000e-05
# Epoch 76/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9460 - loss: 0.1534
# Epoch 76: val_loss improved from 0.17052 to 0.17010, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 83s 122ms/step - accuracy: 0.9460 - loss: 0.1534 - val_accuracy: 0.9385 - val_loss: 0.1701 - learning_rate: 1.0000e-05
# Epoch 77/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9456 - loss: 0.1515
# Epoch 77: val_loss improved from 0.17010 to 0.16986, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 84s 123ms/step - accuracy: 0.9456 - loss: 0.1515 - val_accuracy: 0.9372 - val_loss: 0.1699 - learning_rate: 1.0000e-05
# Epoch 78/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9471 - loss: 0.1515
# Epoch 78: val_loss improved from 0.16986 to 0.16947, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 84s 124ms/step - accuracy: 0.9471 - loss: 0.1515 - val_accuracy: 0.9376 - val_loss: 0.1695 - learning_rate: 1.0000e-05
# Epoch 79/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9465 - loss: 0.1494
# Epoch 79: val_loss improved from 0.16947 to 0.16918, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 86s 125ms/step - accuracy: 0.9465 - loss: 0.1494 - val_accuracy: 0.9372 - val_loss: 0.1692 - learning_rate: 1.0000e-05
# Epoch 80/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9476 - loss: 0.1482
# Epoch 80: val_loss improved from 0.16918 to 0.16878, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 86s 125ms/step - accuracy: 0.9476 - loss: 0.1482 - val_accuracy: 0.9376 - val_loss: 0.1688 - learning_rate: 1.0000e-05
# Epoch 81/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9455 - loss: 0.1490
# Epoch 81: val_loss improved from 0.16878 to 0.16843, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 88s 128ms/step - accuracy: 0.9455 - loss: 0.1490 - val_accuracy: 0.9389 - val_loss: 0.1684 - learning_rate: 1.0000e-05
# Epoch 82/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9472 - loss: 0.1474
# Epoch 82: val_loss improved from 0.16843 to 0.16819, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 87s 127ms/step - accuracy: 0.9472 - loss: 0.1474 - val_accuracy: 0.9372 - val_loss: 0.1682 - learning_rate: 1.0000e-05
# Epoch 83/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9459 - loss: 0.1504
# Epoch 83: val_loss improved from 0.16819 to 0.16796, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 88s 129ms/step - accuracy: 0.9459 - loss: 0.1504 - val_accuracy: 0.9368 - val_loss: 0.1680 - learning_rate: 1.0000e-05
# Epoch 84/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9488 - loss: 0.1462
# Epoch 84: val_loss improved from 0.16796 to 0.16757, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 89s 130ms/step - accuracy: 0.9487 - loss: 0.1462 - val_accuracy: 0.9380 - val_loss: 0.1676 - learning_rate: 1.0000e-05
# Epoch 85/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9446 - loss: 0.1500
# Epoch 85: val_loss improved from 0.16757 to 0.16728, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 90s 131ms/step - accuracy: 0.9446 - loss: 0.1500 - val_accuracy: 0.9376 - val_loss: 0.1673 - learning_rate: 1.0000e-05
# Epoch 86/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9488 - loss: 0.1479
# Epoch 86: val_loss improved from 0.16728 to 0.16696, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 90s 131ms/step - accuracy: 0.9488 - loss: 0.1479 - val_accuracy: 0.9376 - val_loss: 0.1670 - learning_rate: 1.0000e-05
# Epoch 87/100
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9487 - loss: 0.1448
# Epoch 87: val_loss improved from 0.16696 to 0.16658, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 95s 139ms/step - accuracy: 0.9487 - loss: 0.1448 - val_accuracy: 0.9380 - val_loss: 0.1666 - learning_rate: 1.0000e-05
# Epoch 88/100
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9466 - loss: 0.1446
# Epoch 88: val_loss improved from 0.16658 to 0.16626, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 89s 130ms/step - accuracy: 0.9466 - loss: 0.1446 - val_accuracy: 0.9385 - val_loss: 0.1663 - learning_rate: 1.0000e-05
# Epoch 89/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9466 - loss: 0.1474
# Epoch 89: val_loss improved from 0.16626 to 0.16609, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 94s 138ms/step - accuracy: 0.9466 - loss: 0.1474 - val_accuracy: 0.9376 - val_loss: 0.1661 - learning_rate: 1.0000e-05
# Epoch 90/100
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9454 - loss: 0.1505
# Epoch 90: val_loss improved from 0.16609 to 0.16571, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 93s 137ms/step - accuracy: 0.9454 - loss: 0.1505 - val_accuracy: 0.9389 - val_loss: 0.1657 - learning_rate: 1.0000e-05
# Epoch 91/100
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9479 - loss: 0.1481
# Epoch 91: val_loss improved from 0.16571 to 0.16540, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 96s 141ms/step - accuracy: 0.9479 - loss: 0.1481 - val_accuracy: 0.9389 - val_loss: 0.1654 - learning_rate: 1.0000e-05
# Epoch 92/100
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9518 - loss: 0.1397
# Epoch 92: val_loss improved from 0.16540 to 0.16530, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 101s 148ms/step - accuracy: 0.9518 - loss: 0.1397 - val_accuracy: 0.9380 - val_loss: 0.1653 - learning_rate: 1.0000e-05
# Epoch 93/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9463 - loss: 0.1490
# Epoch 93: val_loss improved from 0.16530 to 0.16488, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 97s 143ms/step - accuracy: 0.9463 - loss: 0.1490 - val_accuracy: 0.9389 - val_loss: 0.1649 - learning_rate: 1.0000e-05
# Epoch 94/100
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9487 - loss: 0.1453
# Epoch 94: val_loss improved from 0.16488 to 0.16460, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 95s 139ms/step - accuracy: 0.9487 - loss: 0.1453 - val_accuracy: 0.9389 - val_loss: 0.1646 - learning_rate: 1.0000e-05
# Epoch 95/100
# 682/683 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9445 - loss: 0.1512
# Epoch 95: val_loss improved from 0.16460 to 0.16428, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 95s 140ms/step - accuracy: 0.9445 - loss: 0.1512 - val_accuracy: 0.9397 - val_loss: 0.1643 - learning_rate: 1.0000e-05
# Epoch 96/100
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9498 - loss: 0.1415
# Epoch 96: val_loss improved from 0.16428 to 0.16417, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 101s 148ms/step - accuracy: 0.9498 - loss: 0.1415 - val_accuracy: 0.9393 - val_loss: 0.1642 - learning_rate: 1.0000e-05
# Epoch 97/100
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9476 - loss: 0.1462
# Epoch 97: val_loss improved from 0.16417 to 0.16382, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 141s 147ms/step - accuracy: 0.9476 - loss: 0.1462 - val_accuracy: 0.9393 - val_loss: 0.1638 - learning_rate: 1.0000e-05
# Epoch 98/100
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9461 - loss: 0.1500
# Epoch 98: val_loss improved from 0.16382 to 0.16354, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 102s 149ms/step - accuracy: 0.9461 - loss: 0.1500 - val_accuracy: 0.9393 - val_loss: 0.1635 - learning_rate: 1.0000e-05
# Epoch 99/100
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9476 - loss: 0.1459
# Epoch 99: val_loss improved from 0.16354 to 0.16336, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 100s 147ms/step - accuracy: 0.9476 - loss: 0.1459 - val_accuracy: 0.9402 - val_loss: 0.1634 - learning_rate: 1.0000e-05
# Epoch 100/100
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9494 - loss: 0.1417
# Epoch 100: val_loss improved from 0.16336 to 0.16319, saving model to MobileNetV2ModelWeights.weights.h5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 101s 147ms/step - accuracy: 0.9494 - loss: 0.1417 - val_accuracy: 0.9393 - val_loss: 0.1632 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 97.
#
# Restoring best weights for MobileNetV2
# Total training time: 7960.83 seconds

# %%
#Best Validation Accuracy
best_val_acc = max(history.history['val_accuracy'])
print(f"Best validation Accuracy: {best_val_acc}")
# Out:
# Best validation Accuracy: 0.94017094373703

# %%
#Results
plt.plot(history.history['accuracy'],label = 'Train Accuracy')
plt.plot(history.history['val_accuracy'],label = 'Val Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'],label = 'Train Loss')
plt.plot(history.history['val_loss'],label = 'Val Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# evaluate the network
print("Evaluating network...")
predictions = model.predict(X_test_norm)
preds = predictions > 0.5
# Out:
# Evaluating network...
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 16s 216ms/step

# %%
from collections import Counter
# Get predicted class distribution
predicted_classes = preds.astype(int).flatten()
class_counts = Counter(predicted_classes)

# Plot the class distribution
sns.barplot(x=list(class_counts.keys()), y=list(class_counts.values()), palette="muted")
plt.xticks([0, 1], ['NonViolence', 'Violence'])
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Predicted Class Distribution')
plt.show()
# Out:
# C:\Users\iamid\AppData\Local\Temp\ipykernel_18956\640220170.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(class_counts.keys()), y=list(class_counts.values()), palette="muted")

# %%
# Compute the confusion matrix
corr_pred = confusion_matrix(y_test, preds)

n_correct = int(corr_pred[0][0] + corr_pred[1][1])  # Count of correct predictions
print('> Correct Predictions:', n_correct)

n_wrongs = int(corr_pred[0][1] + corr_pred[1][0])  # Count of wrong predictions
print('> Wrong Predictions:', n_wrongs)

# Plot the confusion matrix using seaborn's heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_pred, annot=True, fmt="d", cmap="Blues", 
            xticklabels=["NonViolence", "Violence"], 
            yticklabels=["NonViolence", "Violence"])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()  # Ensure to call plt.show() to display the plot

# Print the classification report
print(metrics.classification_report(y_test, preds, 
                                     target_names=["NonViolence", "Violence"]))
# Out:
# > Correct Predictions: 2196
# > Wrong Predictions: 144
#               precision    recall  f1-score   support
#
#  NonViolence       0.93      0.93      0.93      1094
#     Violence       0.94      0.94      0.94      1246
#
#     accuracy                           0.94      2340
#    macro avg       0.94      0.94      0.94      2340
# weighted avg       0.94      0.94      0.94      2340

# %%
args_model = "Violence Detection MobileNetV2.h5"
model.save(args_model)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model = load_model("Violence Detection MobileNetV2.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Function to preprocess each frame
def preprocess_frame(frame, img_size=128):
    # Convert BGR to RGB
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    # Resize frame to match model's input size
    frame = cv2.resize(frame, (img_size, img_size))
    # Normalize pixel values
    frame = frame / 255
    # Expand dimensions to match model's input shape (1, 128, 128, 3)
    frame = np.expand_dims(frame, axis=0)
    return frame

# %%
# Function to predict and display frames with labels in real-time
def display_predictions_in_video(video_path):
    cap = cv2.VideoCapture(video_path)
    cap.set(3, 500)  # Set width
    cap.set(4, 450)   # Set height
    violent_frames = []  # List to store frames with violence detected
    
    # Check if the video opened successfully
    if not cap.isOpened():
        print("Error: Could not open video.")
        return
        
    
    frame_count = 0  # Counter to track the frames

    while cap.isOpened():
        success, frame = cap.read()
        
        if success:
            # Only process every 7th frame
            if frame_count % 7 == 0:
                # Preprocess the frame (resize, normalise, etc.)
                processed_frame = preprocess_frame(frame)

                # Predict using the model
                prediction = model.predict(processed_frame)

                # Determine label and corresponding color based on prediction
                if prediction >= 0.9:
                    label = "Violence"
                    color = (0, 0, 255)  # Red in BGR
                    violent_frames.append(frame)
                    
                else:
                    label = "NonViolence"
                    color = (0, 255, 0)  # Green in BGR
                print(f"- Prediction: {label}")

                # Overlay the label on the frame
                label_text = f"Prediction: {label}"
                cv2.putText(frame, label_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, color, 2)

                # Display the frame with the label
                cv2.imshow("Video Prediction", frame)

            frame_count += 1  # Increment the frame counter

            # Press 'q' to quit early
            if cv2.waitKey(30) & 0xFF == ord('q'):
                break
        else:
            print("End of video or read failure.")
            break  # Stop if the video has ended

    cap.release()
    cv2.destroyAllWindows()
    return violent_frames

# %%
def display_stored_violence_frames(violence_frames, rows=6, cols=6):
    num_frames = len(violence_frames)
    fig, axes = plt.subplots(rows, cols, figsize=(cols * 4, rows * 3))
    axes = axes.flatten()  # Flatten the 2D axes array for easier iteration

    for i, ax in enumerate(axes):
        if i < num_frames:
            # Convert BGR to RGB for displaying in Matplotlib
            frame_rgb = cv2.cvtColor(violence_frames[i], cv2.COLOR_BGR2RGB)
            ax.imshow(frame_rgb)
            ax.set_title(f"Frame {i+1}")
            ax.axis("off")  # Hide axes
        else:
            ax.axis("off")  # Hide any unused subplot spaces

    plt.tight_layout()
    plt.show()

# %%
# Test on an unseen video
video_path =  "9.mp4"  # Replace with the video file path
violent_frames = display_predictions_in_video(video_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# - Prediction: NonViolence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# - Prediction: Violence
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# - Prediction: Violence
# End of video or read failure.

# %%
# Display stored violence-detected frames
if violent_frames:
    print(f"Number of violence-detected frames: {len(violent_frames)}")
    display_stored_violence_frames(violent_frames)
else:
    print("No violence-detected frames were stored.")
# Out:
# Number of violence-detected frames: 15
